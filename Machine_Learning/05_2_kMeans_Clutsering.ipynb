# %%
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt

# %%
csvURL = "https://raw.githubusercontent.com/datascienceinc/learn-data-science/master/Introduction-to-K-means-Clustering/Data/data_1024.csv"
df = pd.read_csv(csvURL, delimiter = '\t')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-344dcfbc6c30> in <module>()
#       1 csvURL = "https://raw.githubusercontent.com/datascienceinc/learn-data-science/master/Introduction-to-K-means-Clustering/Data/data_1024.csv"
# ----> 2 df = pd.read_csv(csvURL, delimiter = '\t')
#
# ...

# %%
### For the purposes of this example, we store feature data from our
### dataframe `df`, in the `f1` and `f2` arrays. We combine this into
### a feature matrix `X` before entering it into the algorithm.

f1 = df['Distance_Feature'].values
f2 = df['Speeding_Feature'].values

X=np.matrix(list(zip(f1,f2)))
kmeans = KMeans(n_clusters=2).fit(X)
color = ("red", "blue", "green", "purple")
for l in np.unique(kmeans.labels_):
  ix = np.where(kmeans.labels_ == l)
  plt.scatter(f1[ix], f2[ix], c = color[l], label = l, s = 10)
  
  
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color="black")

plt.legend()

# %%
for l in np.unique(kmeans.labels_):
  ix = np.where(kmeans.labels_ == l)

# %%
from mpl_toolkits.mplot3d import Axes3D

kmeans = KMeans(n_clusters=4).fit(X)

color = ("red", "blue",
         "green", "purple")
for l in np.unique(kmeans.labels_):
  ix = np.where(kmeans.labels_ == l)
  plt.scatter(f1[ix], f2[ix], c = color[l], label = l, s = 10)

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color="black")
plt.legend()
